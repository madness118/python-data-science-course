# %% [markdown]
# # Property Visualization

# %%
# %matplotlib inline
import matplotlib.pyplot as plt # import smthn as smthn else
import matplotlib as mpl
import seaborn as sns
import pandas as pd
import numpy as np
sns.set(color_codes=True) #overide maplot libs ugly colours. Not needed, but optional
mpl.rcParams['figure.figsize'] = [13, 8] #default figure size/how big it is. dont have to

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df = pd.read_csv("/content/drive/MyDrive/python class/Hong_Kong_Clean.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         Unnamed: 0                 addr  ...      lat       lon
# 0                0  BLOCK 4 2#/F Room F  ...  22.2634  114.2403
# 1                1   BLOCK 2 1/F Room J  ...  22.2634  114.2403
# 2                2   BLOCK 5 4/F Room J  ...  22.2634  114.2403
# 3                3  BLOCK 4 1#/F Room G  ...  22.2634  114.2403
# 4                4  BLOCK 5 1#/F Room K  ...  22.2634  114.2403
# ...            ...                  ...  ...      ...       ...
# 429395      429395          2#/F Room A  ...  22.3677  114.0728
# 429396      429396          1#/F Room B  ...  22.3677  114.0728
# 429397      429397          1#/F Room A  ...  22.3677  114.0728
# 429398      429398           5/F Room A  ...  22.3677  114.0728
# 429399      429399          1#/F Room B  ...  22.3677  114.0728
#
# [429400 rows x 27 columns]

# %% [markdown]
# **Plot a graph showing the price per square feet over the years.**

# %%
df.groupby("date").sqft_price.mean().head()
# Out:
# date
# 1996-01-04    3814.484848
# 1996-01-05    4423.180328
# 1996-01-06    4355.967480
# 1996-01-08    4411.106667
# 1996-01-09    2845.986239
# Name: sqft_price, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(13,8))
sns.barplot(palette="hls", ax=ax, data = df,x="date",y="sqft_price")

# %% [markdown]
# **Plot a graph showing the area per square feet against each district.**

# %%
fig, ax= plt.subplots(figsize=(8, 20))
sns.barplot(palette="ch:start=.2,rot=-.3", ax=ax, data = df,x="sqft_area",y="district")

# %% [markdown]
# **Plot a graph showing relationship between floor and the price**

# %%
fig, ax = plt.subplots(figsize=(13,8))
sns.barplot(palette="rocket", ax=ax, data = df,x="floor",y="price")
