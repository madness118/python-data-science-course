# %% [markdown]
# Go to this link https://rapidapi.com/spoonacular/api/recipe-food-nutrition?endpoint=584fe88be4b081971c1b7f39, get your own API key, and complete the following three questions

# %% [markdown]
# 1)Under the Search index in the documentation, use a GET request(Get Wine Description) to get the wineDescription of Merlot

# %%
# Out:
# {"wineDescription":"Merlot is a dry red wine which is smooth and medium bodied."}

# %%
# Out:
# 'Merlot is a dry red wine which is smooth and medium bodied.'

# %% [markdown]
# 2)Under the Compute index in the documentation, use a GET request(Convert Amounts) to convert 2 oz tomatoes into pieces, find the value of pieces

# %%
# Out:
# {"sourceAmount":2.0,"sourceUnit":"oz","targetAmount":0.46,"targetUnit":"piece","answer":"2 oz tomatoes are 0.46 piece.","type":"CONVERSION"}

# %%
# Out:
# '2 oz tomatoes are 0.46 piece.'

# %% [markdown]
# 3)Under the Extract index in the documentation, use a POST request(Parse Ingredients) to get the estimated cost of 4 servings of 3 oz pork shoulder

# %%
# Out:
# [{"id":10072,"original":"3 oz pork shoulder","originalName":"pork shoulder","name":"pork shoulder","amount":3.0,"unit":"oz","unitShort":"oz","unitLong":"ounces","possibleUnits":["pound","piece","g","ounce","oz","cup","serving"],"estimatedCost":{"value":31.01,"unit":"US Cents"},"consistency":"solid","shoppingListUnits":["ounces","pounds"],"aisle":"Meat","image":"pork-shoulder.png","meta":[]}]

# %%
# Out:
# {'value': 31.01, 'unit': 'US Cents'}
